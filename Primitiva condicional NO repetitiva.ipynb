# %% [markdown]
# # **Primitiva condicional NO repetitiva**
#
# En el psedo la estructura vista es:
# ```
# SI(condiciones = verdadero)
# | ins 1
# | ins 2
# | ins 3
# | ins 4
# | ins ..
# SINO
# | ins 1
# | ins 2
# | ins 3
# | ins 4
# | ins ..
# FIN-SI
# ```

# %% [markdown]
# En el lenguaje, usamos la sgte sintaxis
#
#
#
# ```
# if condition = True:
#   st 1
#   st 2
#   st 3
#   st 4
#   st ..
# else:
#   st 1
#   st 2
#   st 3
#   st 4
#   st ..
# ```

# %% [markdown]
# Realice un algoritmo para determinar si un estudiante gana o pierde una asignatura.
#
# Recuerde que:
# - si la nota es inferior a 2.95, el estudiante ha perdido. La nota se mantiene
# - Si La nota está entre 2.95 y menor que 3.0, el sistema la llevará a 3.0. Y gana la asignatura.
# - En otro caso, el estudiante ha ganado. Es decir la nota se mantiene.

# %%
nota = float(input("Ingrese la nota: "))
if nota < 0 or nota > 5:# la nota es incorrecta
  print("Que el intervalo de las notas es de 0.0 a 5.0")
else:# La nota está dentro del rango permitido
  if nota < 2.95:
    print("Has perdido, yaper!😪")
  else:
    if nota >= 2.95 and nota < 3.0:
      nota = 3.0
      print("Has ganado, pero con ayuda")
    else:
      print("¡Has ganado!")
print("La nota definitiva es: ", nota)
# Out:
# Ingrese la nota: 2.95
# Has ganado, pero con ayuda
# La nota definitiva es:  3.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
salario = float(input("Ingrese el salario: "))
tiempo = int(input("Ingrese la cantidad de años en la empresa "))
utilidad = 0
if tiempo < 1:
  utilidad = salario * 0.05

if tiempo >= 1 and tiempo < 2:
  utilidad = salario * 0.07

if tiempo >= 2 and tiempo <5:
  utilidad = salario * 0.10

if tiempo >= 5 and tiempo < 10:
  utilidad = salario * 0.15

if tiempo >= 10:
  utilidad = salario * 0.20

print("Has recibido una utilidad anual de: ", utilidad)
# Out:
# Ingrese el salario: 5254554.23
# Ingrese la cantidad de años en la empresa 5
# Has recibido una utilidad anual de:  788183.1345

# %% [markdown]
# Tarea resuelta

# %%
salario = float(input("Ingrese el salario: "))
tiempo = int(input("Ingrese la cantidad de años en la empresa "))
utilidad = 0
if tiempo < 1:
  utilidad = salario * 0.05
else:
  if tiempo >= 1 and tiempo < 2:
    utilidad = salario * 0.07
  else:
    if tiempo >= 2 and tiempo <5:
      utilidad = salario * 0.10
    else:
      if tiempo >= 5 and tiempo < 10:
        utilidad = salario * 0.15
      else:
        if tiempo >= 10:
          utilidad = salario * 0.20

print("Has recibido una utilidad anual de: ", utilidad)

# %% [markdown]
# Para identar los sino en una sola línea con el si, hacemos uso de elif

# %%
salario = float(input("Ingrese el salario: "))
tiempo = int(input("Ingrese la cantidad de años en la empresa "))
utilidad = 0
if tiempo < 1:
  utilidad = salario * 0.05
elif tiempo >= 1 and tiempo < 2:
  utilidad = salario * 0.07
elif tiempo >= 2 and tiempo <5:
  utilidad = salario * 0.10
elif tiempo >= 5 and tiempo < 10:
  utilidad = salario * 0.15
else:
  utilidad = salario * 0.20

print("Has recibido una utilidad anual de: ", utilidad)
